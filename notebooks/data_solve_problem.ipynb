# %%
from sqlalchemy import create_engine
import os
import numpy as np
import pandas as pd
from dotenv import load_dotenv

def create_connection():

    load_dotenv()
    host = os.environ.get('DB_DESTINATION_HOST')
    port = os.environ.get('DB_DESTINATION_PORT')
    db = os.environ.get('DB_DESTINATION_NAME')
    username = os.environ.get('DB_DESTINATION_USER')
    password = os.environ.get('DB_DESTINATION_PASSWORD')
    
    print(f'postgresql://{username}:{password}@{host}:{port}/{db}')
    conn = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{db}')
    return conn

# установите соединение с базой
conn = create_connection()

data = pd.read_sql('select * from users_churn', conn, parse_dates=['start_date', 'end_date']) 
data.info()
# Out:
# postgresql://mle_20240729_393dbfd5ab:2b9f7f47f6f949a0b0ec2303a63cc76e@rc1b-uh7kdmcx67eomesf.mdb.yandexcloud.net:6432/playground_mle_20240729_393dbfd5ab
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 7043 non-null   int64
#  1   customer_id        7043 non-null   object
#  2   begin_date         7043 non-null   datetime64[ns]
#  3   end_date           1869 non-null   datetime64[ns]
#  4   type               7043 non-null   object
#  5   paperless_billing  7043 non-null   object
#  6   payment_method     7043 non-null   object
#  7   monthly_charges    7043 non-null   float64
#  8   total_charges      7032 non-null   float64
#  9   internet_service   5517 non-null   object
#  10  online_security    5517 non-null   object
#  11  online_backup      5517 non-null   object
#  12  device_protection  5517 non-null   object
#  13  tech_support       5517 non-null   object
#  14  streaming_tv       5517 non-null   object
#  15  streaming_movies   5517 non-null   object
#  16  gender             7043 non-null   object
#  17  senior_citizen     7043 non-null   int64
#  18  partner            7043 non-null   object
#  19  dependents         7043 non-null   object
#  20  multiple_lines     6361 non-null   object
#  21  target             7043 non-null   int64
# dtypes: datetime64[ns](2), float64(2), int64(3), object(15)
# memory usage: 1.2+ MB

# %% [markdown]
# Проверка на дубликаты

# %%
is_duplicated_id = data.duplicated(subset=['customer_id'], keep=False)
# параметр keep = False приводит к тому, что и оригинал, и дубликат помечаются как объект с дубликатом
print(sum(is_duplicated_id))
# Out:
# 0

# %%
feature_cols = []
for item in data.columns:
    if not item in ['id','customer_id']:
        feature_cols.append(item)
print(feature_cols)
# Out:
# ['begin_date', 'end_date', 'type', 'paperless_billing', 'payment_method', 'monthly_charges', 'total_charges', 'internet_service', 'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies', 'gender', 'senior_citizen', 'partner', 'dependents', 'multiple_lines', 'target']

# %%
is_duplicated_features = data.duplicated(subset=feature_cols,keep=False)
print(len(data[is_duplicated_features]))
data[is_duplicated_features].sort_values(feature_cols)
# Out:
# 24
#          id customer_id begin_date   end_date            type  \
# 4392   7980  3428-XZMAZ 2019-10-01 2019-11-01  Month-to-month
# 6234  12738  6457-GIRWB 2019-10-01 2019-11-01  Month-to-month
# 427    6289  1240-KNSEZ 2019-10-01 2019-11-01  Month-to-month
# 6812  12112  1000-AJSLD 2019-10-01 2019-11-01  Month-to-month
# 1792   2455  8375-DKEBR 2019-12-01 2020-01-01  Month-to-month
# 4139   5539  2636-ALXXZ 2019-12-01 2020-01-01  Month-to-month
# 1229    544  2866-IKBTM 2020-01-01        NaT  Month-to-month
# 5053   1976  8605-ITULD 2020-01-01        NaT  Month-to-month
# 4866  12439  0970-QXPXW 2020-01-01        NaT  Month-to-month
# 6976   9272  7721-DVEKZ 2020-01-01        NaT  Month-to-month
# 4607   8539  6654-QGBZZ 2020-01-01        NaT  Month-to-month
# 5733  12303  7878-RTCZG 2020-01-01        NaT  Month-to-month
# 1760    664  3030-ZKIWL 2020-01-01        NaT  Month-to-month
# 3155   6434  7096-UCLNH 2020-01-01        NaT  Month-to-month
# 4269  10393  8749-CLJXC 2020-01-01        NaT  Month-to-month
# 395     102  6380-ARCEH 2020-01-01        NaT  Month-to-month
# 2244   2851  3247-MHJKM 2020-01-01        NaT  Month-to-month
# 6150   9937  8048-DSDFQ 2020-01-01        NaT  Month-to-month
# 4165   5560  9122-UMROB 2020-01-01        NaT  Month-to-month
# 4654  11891  2676-ISHSF 2020-01-01        NaT  Month-to-month
# 3398   3201  0673-IGUQO 2020-01-01        NaT  Month-to-month
# 5741   4722  2668-TZSPS 2020-01-01        NaT  Month-to-month
# 1698    692  8262-COGGB 2020-01-01        NaT  Month-to-month
# 3116   4361  5996-DAOQL 2020-01-01        NaT  Month-to-month
#
#      paperless_billing    payment_method  monthly_charges  total_charges  \
# 4392               Yes  Electronic check            69.35          69.35
# 6234               Yes  Electronic check            69.35          69.35
# 427                Yes      Mailed check            20.10          20.10
# 6812               Yes      Mailed check            20.10          20.10
# 1792               Yes  Electronic check            69.60          69.60
# 4139               Yes  Electronic check            69.60          69.60
# 1229                No      Mailed check            19.55          19.55
# 5053                No      Mailed check            19.55          19.55
# 4866                No      Mailed check            19.65          19.65
# 6976                No      Mailed check            19.65          19.65
# 4607                No      Mailed check            19.90          19.90
# 5733                No      Mailed check            19.90          19.90
# 1760                No      Mailed check            20.05          20.05
# 3155                No      Mailed check            20.05          20.05
# 4269                No      Mailed check            20.05          20.05
# 395                 No      Mailed check            20.20          20.20
# 2244                No      Mailed check            20.20          20.20
# 6150                No      Mailed check            20.20          20.20
# 4165                No      Mailed check            20.30          20.30
# 4654                No      Mailed check            20.30          20.30
# 3398                No      Mailed check            20.45          20.45
# 5741                No      Mailed check            20.45          20.45
# 1698               Yes      Mailed check            20.45          20.45
# 3116               Yes      Mailed check            20.45          20.45
#
#      internet_service  ... device_protection tech_support streaming_tv  \
# 4392      Fiber optic  ...                No           No           No
# 6234      Fiber optic  ...                No           No           No
# 427              None  ...              None         None         None
# 6812             None  ...              None         None         None
# 1792      Fiber optic  ...                No           No           No
# 4139      Fiber optic  ...                No           No           No
# 1229             None  ...              None         None         None
# 5053             None  ...              None         None         None
# 4866             None  ...              None         None         None
# 6976             None  ...              None         None         None
# 4607             None  ...              None         None         None
# 5733             None  ...              None         None         None
# 1760             None  ...              None         None         None
# 3155             None  ...              None         None         None
# 4269             None  ...              None         None         None
# 395              None  ...              None         None         None
# 2244             None  ...              None         None         None
# 6150             None  ...              None         None         None
# 4165             None  ...              None         None         None
# 4654             None  ...              None         None         None
# 3398             None  ...              None         None         None
# 5741             None  ...              None         None         None
# 1698             None  ...              None         None         None
# 3116             None  ...              None         None         None
#
#      streaming_movies  gender senior_citizen partner  dependents  \
# 4392               No    Male              0      No          No
# 6234               No    Male              0      No          No
# 427              None    Male              0      No          No
# 6812             None    Male              0      No          No
# 1792               No  Female              1      No          No
# 4139               No  Female              1      No          No
# 1229             None  Female              0      No          No
# 5053             None  Female              0      No          No
# 4866             None  Female              0      No          No
# 6976             None  Female              0      No          No
# 4607             None  Female              0      No          No
# 5733             None  Female              0      No          No
# 1760             None    Male              0      No          No
# 3155             None    Male              0      No          No
# 4269             None    Male              0      No          No
# 395              None    Male              0      No          No
# 2244             None    Male              0      No          No
# 6150             None    Male              0      No          No
# 4165             None    Male              0      No          No
# 4654             None    Male              0      No          No
# 3398             None    Male              0      No          No
# 5741             None    Male              0      No          No
# 1698             None    Male              0      No          No
# 3116             None    Male              0      No          No
#
#      multiple_lines target
# 4392             No      1
# 6234             No      1
# 427              No      1
# 6812             No      1
# 1792             No      1
# 4139             No      1
# 1229             No      0
# 5053             No      0
# 4866             No      0
# 6976             No      0
# 4607             No      0
# 5733             No      0
# 1760             No      0
# 3155             No      0
# 4269             No      0
# 395              No      0
# 2244             No      0
# 6150             No      0
# 4165             No      0
# 4654             No      0
# 3398             No      0
# 5741             No      0
# 1698             No      0
# 3116             No      0
#
# [24 rows x 22 columns]

# %%
data = data[~is_duplicated_features].reset_index(drop=True)

# %%
print(data.shape)
# Out:
# (7019, 22)

# %%
def remove_duplicates(data):
    feature_cols = data.columns.drop('customer_id').tolist()
    is_duplicated_features = data.duplicated(subset=feature_cols, keep=False)
    data = data[~is_duplicated_features].reset_index(drop=True)
    return data

# %% [markdown]
# ПРОПУСКИ
# В случае с числовыми колонками наиболее распространённый подход — заполнение средним или медианным значением, а в случае с категориальными — заполнение модой.

# %%
data.isnull().sum()
# Out:
# id                      0
# customer_id             0
# begin_date              0
# end_date             5156
# type                    0
# paperless_billing       0
# payment_method          0
# monthly_charges         0
# total_charges          11
# internet_service     1506
# online_security      1506
# online_backup        1506
# device_protection    1506
# tech_support         1506
# streaming_tv         1506
# streaming_movies     1506
# gender                  0
# senior_citizen          0
# partner                 0
# dependents              0
# multiple_lines        682
# target                  0
# dtype: int64

# %% [markdown]
# Список колонок с пустыми значениями

# %%
cols_with_nans = data.isnull().sum()
cols_with_nans = cols_with_nans[cols_with_nans > 0].index.drop('end_date')
cols_with_nans
# Out:
# Index(['total_charges', 'internet_service', 'online_security', 'online_backup',
#        'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
#        'multiple_lines'],
#       dtype='object')

# %% [markdown]
# Заполняем средники, а категории модой

# %%
for col in cols_with_nans:
	if data[col].dtype in [float, int]:
		fill_value = data[col].mean
	elif data[col].dtype == 'object':
		fill_value = data[col].mode().iloc[0]
	data[col] = data[col].fillna(fill_value)

# %% [markdown]
# проверяем пустые поля

# %%
data.isnull().sum()
# Out:
# id                      0
# customer_id             0
# begin_date              0
# end_date             5156
# type                    0
# paperless_billing       0
# payment_method          0
# monthly_charges         0
# total_charges           0
# internet_service        0
# online_security         0
# online_backup           0
# device_protection       0
# tech_support            0
# streaming_tv            0
# streaming_movies        0
# gender                  0
# senior_citizen          0
# partner                 0
# dependents              0
# multiple_lines          0
# target                  0
# dtype: int64

# %% [markdown]
# функция заполнения пропусков

# %%
def fill_missing_values(data):
    cols_with_nans = data.isnull().sum()
    cols_with_nans = cols_with_nans[cols_with_nans > 0].index.drop('end_date')
    for col in cols_with_nans:
        if data[col].dtype in [float, int]:
            fill_value = data[col].mean()
        elif data[col].dtype == 'object':
            fill_value = data[col].mode().iloc[0]
        data[col] = data[col].fillna(fill_value)
    return data

# %% [markdown]
# Выбросы

# %%
num_cols = data.select_dtypes(['float']).columns
threshold = 1.5
potential_outliers = pd.DataFrame()

for col in num_cols:
	Q1 = data[col].quantile(0.25)
	Q3 = data[col].quantile(0.75)
	IQR = Q3 - Q1
	margin = threshold*IQR
	lower = Q1 - margin
	upper = Q3 + margin
	potential_outliers[col] = ~data[col].between(lower, upper)

outliers = potential_outliers.any(axis=1)

print(data[outliers])
# Out:
# Empty DataFrame
# Columns: [id, customer_id, begin_date, end_date, type, paperless_billing, payment_method, monthly_charges, total_charges, internet_service, online_security, online_backup, device_protection, tech_support, streaming_tv, streaming_movies, gender, senior_citizen, partner, dependents, multiple_lines, target]
# Index: []
#
# [0 rows x 22 columns]
